# %% [markdown]
# # NLP

# %% [markdown]
# NLP trata de aplicaciones que entiendan nuestro idioma, reconocimiento de voz, traducción, comprensión semántica, análisis de sentimiento..

# %% [markdown]
# **Usos**
#
# + Motores de búsqueda
# + Feed de redes sociales
# + Asistentes de voz
# + Filtros de span
# + Chatbots

# %% [markdown]
# **Librerías**
#
# + NLTK
# + Spacy
# + TFIDF
# + OpenNLP

# %% [markdown]
# La dificultad del NLP está en varios niveles:
#
# + Ambigüedad:
#
#   * Nivel léxico: por ejemplo, varios significados
#   * Nivel referencial: anáforas, metáforas, etc...
#   * Nivel estructural: la semántica es necesaria para entender la estructura de una oración
#   * Nivel pragmático: dobles sentidos, ironía, humor
#
# + Detección de espacios
# + Recepción imperfecta: acentos, -ismos, OCR

# %% [markdown]
# El proceso es similar que en USL, primero se vectorizan las palabras y después se miden sus distancias/similitudes.

# %%
# lista de 100 peliculas

titles=open('data/title_list.txt').read().split('\n')[:100]

titles[:15]
# Out:
# ['The Godfather',
#  'The Shawshank Redemption',
#  "Schindler's List",
#  'Raging Bull',
#  'Casablanca',
#  "One Flew Over the Cuckoo's Nest",
#  'Gone with the Wind',
#  'Citizen Kane',
#  'The Wizard of Oz',
#  'Titanic',
#  'Lawrence of Arabia',
#  'The Godfather: Part II',
#  'Psycho',
#  'Sunset Blvd.',
#  'Vertigo']

# %%
synopsis=open('data/synopses_list.txt').read().split('\n BREAKS HERE')[:100]

synopsis[0][:200]
# Out:
# " Plot  [edit]  [  [  edit  edit  ]  ]  \n  On the day of his only daughter's wedding, Vito Corleone hears requests in his role as the Godfather, the Don of a New York crime family. Vito's youngest son,"

# %% [markdown]
# ### Limpieza

# %%
#!pip3 install spacy

# %%
import string
import spacy

from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English

import re

# %%
nlp=spacy.load('en')

parser=English()

# %%
def spacy_tokenizer(sentence):
    
    tokens=parser(sentence)
    
    filtered_tokens=[]
    for word in tokens:
        lemma=word.lemma_.lower().strip()
        
        if lemma not in STOP_WORDS and re.search('^[a-zA-Z]+$', lemma):
            filtered_tokens.append(lemma)
            
    return filtered_tokens

# %%
spacy_tokenizer(synopsis[0][:200])
# Out:
# ['plot',
#  'edit',
#  'edit',
#  'edit',
#  'day',
#  'daughter',
#  'wedding',
#  'vito',
#  'corleone',
#  'hears',
#  'requests',
#  'role',
#  'godfather',
#  'don',
#  'new',
#  'york',
#  'crime',
#  'family',
#  'vito',
#  'youngest',
#  'son']

# %% [markdown]
# ### TFIDF (term frequency inverse document frequency)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(min_df=.15, tokenizer=spacy_tokenizer)

# %%
tfidf_matrix=tfidf.fit_transform(synopsis)

# %%
tfidf_matrix.shape
# Out:
# (100, 254)

# %%
tfidf_matrix
# Out:
# <100x254 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6489 stored elements in Compressed Sparse Row format>

# %%
import pandas as pd
pd.DataFrame(tfidf_matrix).head()
# Out:
#                                                    0
# 0    (0, 171)\t0.015782503757703084\n  (0, 53)\t0...
# 1    (0, 171)\t0.016707243705417485\n  (0, 53)\t0...
# 2    (0, 171)\t0.017879690869526076\n  (0, 53)\t0...
# 3    (0, 171)\t0.012541408775298609\n  (0, 53)\t0...
# 4    (0, 171)\t0.016972872543944847\n  (0, 53)\t0...

# %%
terms=tfidf.get_feature_names()
terms[:15]
# Out:
# ['able',
#  'agrees',
#  'air',
#  'american',
#  'apartment',
#  'army',
#  'arrive',
#  'arrives',
#  'asks',
#  'attack',
#  'attempt',
#  'attempts',
#  'attention',
#  'away',
#  'battle']

# %% [markdown]
# ### Distancias

# %%
from sklearn.metrics.pairwise import cosine_similarity as cos

# %%
dist=1-cos(tfidf_matrix)

dist.shape
# Out:
# (100, 100)

# %% [markdown]
# ### Clustering

# %%
import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
# %matplotlib inline
set_matplotlib_formats('svg')

import numpy as np

# %%
from umap import UMAP

# %%
umap=UMAP(n_neighbors=5, random_state=42)
emb=umap.fit_transform(dist)

# %%
emb[:5]
# Out:
# array([[-1.4891616 ,  4.0788736 ],
#        [-1.7629136 ,  0.16342701],
#        [-4.7745385 ,  2.5759263 ],
#        [-0.6867237 ,  0.73427945],
#        [-0.8975087 ,  2.8176866 ]], dtype=float32)

# %%
plt.scatter(emb[:,0], emb[:,1]);

# %%
from hdbscan import HDBSCAN

# %%
hdbscan=HDBSCAN(min_cluster_size=5)

clusters=hdbscan.fit_predict(emb)

# %%
np.unique(clusters)
# Out:
# array([-1,  0,  1,  2,  3])

# %%
plt.scatter(emb[:,0], emb[:,1], c=clusters);

# %% [markdown]
# ### titulos de los clusters

# %%
def get_titles_from_cluster(c):
    return pd.Series(titles)[clusters==c]

# %%
get_titles_from_cluster(2)
# Out:
# 37                            Unforgiven
# 49                                  Jaws
# 52    Butch Cassidy and the Sundance Kid
# 53      The Treasure of the Sierra Madre
# 56                             High Noon
# dtype: object

# %%
tfidf_df=pd.DataFrame(tfidf_matrix.toarray(), columns=terms)

tfidf_df.head()
# Out:
#    able    agrees       air  american  apartment      army    arrive  \
# 0   0.0  0.064639  0.000000  0.000000        0.0  0.000000  0.000000
# 1   0.0  0.000000  0.000000  0.000000        0.0  0.000000  0.074787
# 2   0.0  0.073228  0.000000  0.000000        0.0  0.121965  0.000000
# 3   0.0  0.000000  0.069901  0.089895        0.0  0.085550  0.000000
# 4   0.0  0.069514  0.000000  0.081106        0.0  0.077186  0.075976
#
#     arrives      asks  attack  ...  window  woman      work   working  \
# 0  0.000000  0.053967     0.0  ...     0.0    0.0  0.000000  0.000000
# 1  0.000000  0.000000     0.0  ...     0.0    0.0  0.000000  0.091133
# 2  0.146456  0.061139     0.0  ...     0.0    0.0  0.000000  0.000000
# 3  0.000000  0.128654     0.0  ...     0.0    0.0  0.000000  0.000000
# 4  0.000000  0.000000     0.0  ...     0.0    0.0  0.079747  0.000000
#
#       world  wounded     year     years      york  young
# 0  0.000000      0.0  0.07811  0.062870  0.159100    0.0
# 1  0.073637      0.0  0.00000  0.133108  0.000000    0.0
# 2  0.197012      0.0  0.00000  0.000000  0.000000    0.0
# 3  0.000000      0.0  0.06207  0.000000  0.189641    0.0
# 4  0.000000      0.0  0.00000  0.000000  0.000000    0.0
#
# [5 rows x 254 columns]

# %%
tfidf_df.shape
# Out:
# (100, 254)

# %%
def get_df_from_cluster(c):
    return tfidf_df[clusters==c]

# %%
get_df_from_cluster(3).head()
# Out:
#     able    agrees       air  american  apartment      army    arrive  \
# 10   0.0  0.000000  0.000000  0.074369        0.0  0.176937  0.000000
# 19   0.0  0.000000  0.000000  0.000000        0.0  0.000000  0.000000
# 24   0.0  0.000000  0.000000  0.000000        0.0  0.103461  0.067893
# 29   0.0  0.000000  0.325392  0.000000        0.0  0.168951  0.047515
# 31   0.0  0.074873  0.101893  0.087359        0.0  0.083137  0.000000
#
#     arrives      asks    attack  ...  window  woman      work   working  \
# 10      0.0  0.053217  0.077024  ...     0.0    0.0  0.000000  0.000000
# 19      0.0  0.000000  0.172417  ...     0.0    0.0  0.000000  0.000000
# 24      0.0  0.103726  0.000000  ...     0.0    0.0  0.213789  0.082732
# 29      0.0  0.000000  0.315204  ...     0.0    0.0  0.000000  0.057900
# 31      0.0  0.062512  0.226194  ...     0.0    0.0  0.085895  0.000000
#
#        world   wounded  year     years  york  young
# 10  0.171486  0.000000   0.0  0.000000   0.0    0.0
# 19  0.000000  0.000000   0.0  0.000000   0.0    0.0
# 24  0.100274  0.238274   0.0  0.000000   0.0    0.0
# 29  0.046784  0.000000   0.0  0.042284   0.0    0.0
# 31  0.000000  0.191465   0.0  0.000000   0.0    0.0
#
# [5 rows x 254 columns]

# %%
get_df_from_cluster(3).T.head()
# Out:
#                  10   19   24        29        31   33        34        36  \
# able       0.000000  0.0  0.0  0.000000  0.000000  0.0  0.061875  0.000000
# agrees     0.000000  0.0  0.0  0.000000  0.074873  0.0  0.000000  0.000000
# air        0.000000  0.0  0.0  0.325392  0.101893  0.0  0.000000  0.000000
# american   0.074369  0.0  0.0  0.000000  0.087359  0.0  0.000000  0.354101
# apartment  0.000000  0.0  0.0  0.000000  0.000000  0.0  0.000000  0.000000
#
#                  38        48   50        55        57        61   62  \
# able       0.000000  0.000000  0.0  0.000000  0.000000  0.061057  0.0
# agrees     0.000000  0.000000  0.0  0.000000  0.000000  0.045844  0.0
# air        0.119018  0.000000  0.0  0.145862  0.000000  0.062387  0.0
# american   0.000000  0.235823  0.0  0.062528  0.190484  0.133720  0.0
# apartment  0.000000  0.000000  0.0  0.000000  0.000000  0.000000  0.0
#
#                  79        88
# able       0.000000  0.000000
# agrees     0.000000  0.064563
# air        0.084522  0.000000
# american   0.000000  0.000000
# apartment  0.000000  0.000000

# %%
top_words_cluster=get_df_from_cluster(3).T.sum(axis=1).sort_values(ascending=False)

top_words_cluster.head()
# Out:
# army        2.727777
# general     2.264080
# soldiers    2.253071
# battle      2.033972
# war         2.028721
# dtype: float64

# %% [markdown]
# ## NLP_es

# %%
#!python3 -m spacy download es_core_news_md

# %%
nlp=spacy.load('es_core_news_md')

# %%
doc2vec=nlp('hola me llamo Pepe').vector.sum()

# %%
word2vec=(nlp('hola').vector+nlp('me').vector+nlp('llamo').vector+nlp('Pepe').vector).sum()/4

# %%
doc2vec
# Out:
# 3.9176705

# %%
word2vec
# Out:
# 3.917670488357544

# %% [markdown]
# ##### similitud

# %%
nlp('quiero saludar a todos los alumnos de ironhack').similarity(nlp('quiero dar saludos'))
# Out:
# 0.8303984204423167

# %%
tokens_1=spacy_tokenizer('quiero saludar a todos')
tokens_2=spacy_tokenizer('saludos al perro')

# %%
def get_simil(t1, t2):
    return nlp(' '.join(t1)).similarity(nlp(' '.join(t2)))

# %%
get_simil(tokens_1, tokens_2)
# Out:
# 0.8416365657002934

# %% [markdown]
# # WordClouds

# %%
# librerias

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
from PIL import Image

import string
import spacy
from spacy.lang.en.stop_words import STOP_WORDS
from spacy.lang.en import English
# !python3 -m spacy download en
from spacy.lang.es import Spanish
# !python3 -m spacy download es_core_news_md


import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words_sp=set(stopwords.words('spanish'))
stop_words_en=set(stopwords.words('english'))
stop_words=stop_words_sp | stop_words_en


import re

from langdetect import detect

from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to /Users/data/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def tokenizer(txt):  # texto
    
    if detect(txt)=='en':    # si el texto esta en ingles...
        nlp=spacy.load('en')
        parser=English()
        
    elif detect(txt)=='es':   # si el texto esta en castellano...
        nlp=spacy.load('es_core_news_md')
        parser=Spanish()
        
    else:
        return 'No es castellano ni ingles.'
    
    tokens=parser(txt)
    
    filtered_tokens=[]
    
    for word in tokens:
        lemma=word.lemma_.lower().strip()
        if lemma not in STOP_WORDS and re.search('^[a-zA-Z]+$', lemma):
            filtered_tokens.append(lemma)
    
    return ' '.join(filtered_tokens)

# %%
def wordcloud(df, col):
    
    wordcloud=WordCloud(width=1600,
                        height=400,
                        stopwords=stop_words).generate(' '.join([e for e in df[col]]))
    
    plt.figure(figsize=(15, 10), facecolor='k')
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.tight_layout(pad=0)
    plt.savefig('data/wordcloud.png', facecolor='k', bbox_inches='tight')
    plt.show();

# %%
# texto

txt=open('data/synopses_list.txt').read().split('\n BREAKS HERE')[:100]

# %%
# paso a df

df=pd.DataFrame(txt, columns=['text'])

df.text=df.text.apply(tokenizer)

df.head()
# Out:
#                                                 text
# 0  plot edit edit edit day daughter wedding vito ...
# 1  plot edit edit edit banker andy dufresne convi...
# 2  plot edit edit edit germans polish jews ghetto...
# 3  plot edit edit edit brief scene aging overweig...
# 4  plot edit edit edit early december american ex...

# %%
# wordcloud

wordcloud(df, 'text')

# %%
# en castellano

txt2=open('data/conde.txt').read().split('\n BREAKS HERE')[:100]

df2=pd.DataFrame(txt2, columns=['text'])

df2.text=df2.text.apply(tokenizer)

wordcloud(df2, 'text')

# %% [markdown]
# #### Mascara

# %%
# imagen mascara

vino_mask=np.array(Image.open('data/vino.png'))

# %%
# transformacion de la mascara

def transform(val):
    if val==0:
        return 255
    else:
        return val

# %%
t_vino_mask=np.ndarray((vino_mask.shape[0], vino_mask.shape[1]), np.int32)


for i in range(len(vino_mask)):
    t_vino_mask[i]=list(map(transform, vino_mask[i]))

# %%
w=WordCloud(background_color='white',
            max_words=1000,
            mask=t_vino_mask,
            stopwords=stop_words,
            contour_width=3,
            contour_color='firebrick').generate(' '.join([e for e in df.text]))


w.to_file('data/copa&botella.png')

plt.figure(figsize=(15, 10))
plt.imshow(w, interpolation='bilinear')
plt.axis('off')
plt.show();

# %% [markdown]
# ### ejemplo con todo

# %%
def tokenizer(lst):  # ahora entra una lista
    
    en=0
    es=0
    
    for txt in lst:
        try:
            txt=str(txt)
            if detect(txt)=='en':    # si el texto esta en ingles...
                en+=1
                
                nlp=spacy.load('en')
                parser=English()
                tokens=parser(txt)

                tokens_en=[]

                for word in tokens:
                    lemma=word.lemma_.lower().strip()
                    if lemma not in STOP_WORDS and re.search('^[a-zA-Z]+$', lemma):
                        tokens_en.append(lemma)

            elif detect(txt)=='es':   # si el texto esta en castellano...
                es+=1
                
                nlp=spacy.load('es_core_news_md')
                parser=Spanish()
                tokens=parser(txt)

                tokens_es=[]

                for word in tokens:
                    lemma=word.lemma_.lower().strip()
                    if lemma not in STOP_WORDS and re.search('^[a-zA-Z]+$', lemma):
                        tokens_es.append(lemma)

            else:
                print ('No se reconoce idioma (EN / ES)...')
        
        except:
            print ('ERROR...')
            continue
    
    
    return ' '.join(tokens_en), ' '.join(tokens_es), en, es

# %%
# texto con los dos idiomas

mix_text=txt+txt2

tokens=tokenizer(mix_text)

# %%
# wordcloud ingles

serie_en=pd.DataFrame({'en':tokens[0]}, index=[0])

wordcloud(serie_en, 'en')

# %%
# wordcloud castellano

serie_es=pd.DataFrame({'es':tokens[1]}, index=[0])

wordcloud(serie_es, 'es')

# %%
tokens[2]
# Out:
# 100

# %%
tokens[3]
# Out:
# 1
